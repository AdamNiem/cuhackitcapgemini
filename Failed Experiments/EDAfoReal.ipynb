# %%
import pandas as pd

# %%
df = pd.read_excel('Belt Sample Data.xlsx', dtype=str)
df
# Out:
#                 Name            Timestamp   Status Description  \
# 0    Conveyor Belt 4  2025-08-15 00:00:00  Running         NaN
# 1    Conveyor Belt 4  2025-08-15 00:15:00  Running         NaN
# 2    Conveyor Belt 4  2025-08-15 00:30:00  Running         NaN
# 3    Conveyor Belt 4  2025-08-15 00:45:00  Running         NaN
# 4    Conveyor Belt 4  2025-08-15 01:00:00  Running         NaN
# ..               ...                  ...      ...         ...
# 285  Conveyor Belt 4  2025-08-17 23:15:00  Running         NaN
# 286  Conveyor Belt 4  2025-08-17 23:30:00  Running         NaN
# 287  Conveyor Belt 4  2025-08-17 23:45:00  Running         NaN
# 288  Conveyor Belt 4  2025-08-18 00:00:00  Running         NaN
# 289  Conveyor Belt 4  2025-08-18 00:15:00  Running         NaN
#
#     Vibration Frequency Vibration Amplitude Bearing Temperature  \
# 0               1490.82                0.04               77.13
# 1               1498.37                0.04              77.076
# ...

# %%
df = pd.read_excel('Belt 3 Test Data.xlsx', dtype=str)
df
# Out:
#       Conveyor Belt 4  2026-05-14 00:15:00  Running Unnamed: 3  1498.37  0.04  \
# 0     Conveyor Belt 4  2026-05-14 00:30:00  Running        NaN  1503.22  0.06
# 1     Conveyor Belt 4  2026-05-14 00:45:00  Running        NaN  1508.11  0.04
# 2     Conveyor Belt 4  2026-05-14 01:00:00  Running        NaN  1498.13  0.06
# 3     Conveyor Belt 4  2026-05-14 01:15:00  Running        NaN  1494.89  0.05
# 4     Conveyor Belt 4  2026-05-14 01:30:00  Running        NaN   1498.2  0.06
# ...               ...                  ...      ...        ...      ...   ...
# 1270  Conveyor Belt 4  2026-05-27 06:00:00  Running        NaN  1498.91  0.04
# 1271  Conveyor Belt 4  2026-05-27 06:15:00  Running        NaN  1527.77  0.05
# 1272  Conveyor Belt 4  2026-05-27 06:30:00  Running        NaN  1500.02  0.06
# 1273  Conveyor Belt 4  2026-05-27 06:45:00  Running        NaN  1503.17  0.05
# 1274  Conveyor Belt 4  2026-05-27 07:00:00  Running        NaN  1493.51  0.05
#
# ...

# %%
df['Description'] = df['Description'].astype(str)
df["Description"]
# Out:
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 285    nan
# 286    nan
# 287    nan
# 288    nan
# 289    nan
# Name: Description, Length: 290, dtype: object

# %%
df = pd.read_excel('Belt Sample Result Sheet.xlsx', header=None)
df
# Out:
#         0                   1
# 0  Belt 1 2025-08-20 02:00:00
# 1     NaN                 NaT
# 2  Belt 2 2025-08-29 15:30:00
# 3     NaN                 NaT
# 4  Belt 3 2025-09-11 23:00:00
# 5     NaN                 NaT
# 6  Belt 4 2025-08-25 20:00:00
# 7     NaN                 NaT
# 8  Belt 5 2025-08-27 01:30:00
